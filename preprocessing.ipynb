# %%
import pandas as pd
country_to_continent = {
    'United States': 'North America',
    'China': 'Asia',
    'Japan': 'Asia',
    'Germany': 'Europe',
    'India': 'Asia',
    'United Kingdom': 'Europe',
    'France': 'Europe',
    'Russia': 'Europe',
    'Canada': 'North America',
    'Italy': 'Europe',
    'Brazil': 'South America',
    'Australia': 'Oceania',
    'South Korea': 'Asia',
    'Mexico': 'North America',
    'Spain': 'Europe',
    'Indonesia': 'Asia',
    'Saudi Arabia': 'Asia',
    'Netherlands': 'Europe',
    'Turkey': 'Asia',
    'Switzerland': 'Europe',
    'Poland': 'Europe',
    'Argentina': 'South America',
    'Sweden': 'Europe',
    'Norway': 'Europe',
    'Belgium': 'Europe',
    'Ireland': 'Europe',
    'Israel': 'Asia',
    'United Arab Emirates': 'Asia',
    'Thailand': 'Asia',
    'Nigeria': 'Africa',
    'Egypt': 'Africa',
    'Austria': 'Europe',
    'Singapore': 'Asia',
    'Bangladesh': 'Asia',
    'Vietnam': 'Asia',
    'Malaysia': 'Asia',
    'South Africa': 'Africa',
    'Philippines': 'Asia',
    'Denmark': 'Europe',
    'Iran': 'Asia',
    'Pakistan': 'Asia',
    'Hong Kong': 'Asia',
    'Colombia': 'South America',
    'Romania': 'Europe',
    'Chile': 'South America',
    'Czech Republic (Czechia)': 'Europe',
    'Finland': 'Europe',
    'Iraq': 'Asia',
    'Portugal': 'Europe',
    'New Zealand': 'Oceania',
    'Peru': 'South America',
    'Qatar': 'Asia',
    'Kazakhstan': 'Asia',
    'Greece': 'Europe',
    'Algeria': 'Africa',
    'Kuwait': 'Asia',
    'Hungary': 'Europe',
    'Ukraine': 'Europe',
    'Morocco': 'Africa',
    'Ethiopia': 'Africa',
    'Slovakia': 'Europe',
    'Ecuador': 'South America',
    'Oman': 'Asia',
    'Dominican Republic': 'North America',
    'Kenya': 'Africa',
    'Angola': 'Africa',
    'Guatemala': 'North America',
    'Bulgaria': 'Europe',
    'Luxembourg': 'Europe',
    'Uzbekistan': 'Asia',
    'Azerbaijan': 'Asia',
    'Panama': 'North America',
    'Tanzania': 'Africa',
    'Sri Lanka': 'Asia',
    'Ghana': 'Africa',
    'Belarus': 'Europe',
    'Uruguay': 'South America',
    'Croatia': 'Europe',
    'Lithuania': 'Europe',
    'Côte d\'Ivoire': 'Africa',
    'Costa Rica': 'North America',
    'Serbia': 'Europe',
    'Slovenia': 'Europe',
    'Myanmar': 'Asia',
    'DR Congo': 'Africa',
    'Sudan': 'Africa',
    'Jordan': 'Asia',
    'Tunisia': 'Africa',
    'Libya': 'Africa',
    'Uganda': 'Africa',
    'Bahrain': 'Asia',
    'Cameroon': 'Africa',
    'Bolivia': 'South America',
    'Paraguay': 'South America',
    'Latvia': 'Europe',
    'Nepal': 'Asia',
    'Estonia': 'Europe',
    'El Salvador': 'North America',
    'Honduras': 'North America',
    'Papua New Guinea': 'Oceania',
    'Cambodia': 'Asia',
    'Zambia': 'Africa',
    'Cyprus': 'Asia',
    'Trinidad and Tobago': 'North America',
    'Iceland': 'Europe',
    'Senegal': 'Africa',
    'Georgia': 'Asia',
    'Bosnia and Herzegovina': 'Europe',
    'Macao': 'Asia',
    'Guinea': 'Africa',
    'Gabon': 'Africa',
    'Zimbabwe': 'Africa',
    'Botswana': 'Africa',
    'Haiti': 'North America',
    'Armenia': 'Asia',
    'State of Palestine': 'Asia',
    'Burkina Faso': 'Africa',
    'Albania': 'Europe',
    'Mali': 'Africa',
    'Mozambique': 'Africa',
    'Malta': 'Europe',
    'Benin': 'Africa',
    'Jamaica': 'North America',
    'Mongolia': 'Asia',
    'Brunei': 'Asia',
    'Laos': 'Asia',
    'Nicaragua': 'North America',
    'Guyana': 'South America',
    'Madagascar': 'Africa',
    'Congo': 'Africa',
    'Moldova': 'Europe',
    'Niger': 'Africa',
    'North Macedonia': 'Europe',
    'Rwanda': 'Africa',
    'Malawi': 'Africa',
    'Mauritius': 'Africa',
    'Bahamas': 'North America',
    'Chad': 'Africa',
    'Namibia': 'Africa',
    'Equatorial Guinea': 'Africa',
    'Kyrgyzstan': 'Asia',
    'Tajikistan': 'Asia',
    'Mauritania': 'Africa',
    'Togo': 'Africa',
    'Maldives': 'Asia',
    'Montenegro': 'Europe',
    'Barbados': 'North America',
    'Fiji': 'Oceania',
    'Eswatini': 'Africa',
    'Liberia': 'Africa',
    'Sierra Leone': 'Africa',
    'Suriname': 'South America',
    'Andorra': 'Europe',
    'Timor-Leste': 'Asia',
    'Burundi': 'Africa',
    'Belize': 'North America',
    'Lesotho': 'Africa',
    'Central African Republic': 'Africa',
    'Cabo Verde': 'Africa',
    'Gambia': 'Africa',
    'Saint Lucia': 'North America',
    'Antigua and Barbuda': 'North America',
    'Guinea-Bissau': 'Africa',
    'Solomon Islands': 'Oceania',
    'Seychelles': 'Africa',
    'Grenada': 'North America',
    'Comoros': 'Africa',
    'Vanuatu': 'Oceania',
    'Saint Kitts & Nevis': 'North America',
    'St. Vincent & Grenadines': 'North America',
    'Samoa': 'Oceania',
    'Dominica': 'North America',
    'Sao Tome & Principe': 'Africa',
    'Micronesia': 'Oceania',
    'Marshall Islands': 'Oceania',
    'Kiribati': 'Oceania',
    'Tuvalu': 'Oceania',
    # Continue adding entries for other countries...
}

dataset = pd.read_csv('gdp_countries.csv')

# %%
dataset['Continent'] = dataset['Country'].map(country_to_continent)

# %%
dataset.head()
# Out:
#    #        Country          GDP_Nominal        GDP_abbrev GDP_growth  \
# 0  1  United States  $25,462,700,000,000  $25.463 trillion      2.06%
# 1  2          China  $17,963,200,000,000  $17.963 trillion      2.99%
# 2  3          Japan   $4,231,140,000,000   $4.231 trillion      1.03%
# 3  4        Germany   $4,072,190,000,000   $4.072 trillion      1.79%
# 4  5          India   $3,385,090,000,000   $3.385 trillion      7.00%
#
#    Population GDP_PerCapita Share_of_WorldGDP      Continent
# 0   338289857       $75,269            25.32%  North America
# 1  1425887337       $12,598            17.86%           Asia
# 2   123951692       $34,135             4.21%           Asia
# 3    83369843       $48,845             4.05%         Europe
# 4  1417173173        $2,389             3.37%           Asia

# %%
dataset.to_csv('gdp_countries.csv', index=False)
